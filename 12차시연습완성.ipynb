# %%
# c:\doit\ 폴더가 작업 폴더, c:\doit\data\ 폴더가 데이터 저장 폴더

## Step 0. 필요한 모듈과 라이브러리를 로딩하고 검색어를 입력 받습니다

from bs4 import BeautifulSoup     
from selenium import webdriver
import time
import sys
import os
import re
import math
import numpy
import pandas as pd
import xlwt

##Step 2. 사용자에게 검색어 키워드를 입력 받습니다.
print("=" *80)
print("대한민국 구석구석 사이트의 모든 여행지 정보 수집하기")
print("=" *80)
# Out:
# ================================================================================
# 대한민국 구석구석 사이트의 모든 여행지 정보 수집하기
# ================================================================================

# %%
#query_txt = input('크롤링할 키워드는 무엇입니까?: ')
query_txt = '가을 여행'

f_dir = input("결과 파일을 저장할 폴더명만 쓰세요(없으면 :c:\\doit\\data\\):")

if f_dir == '':
    f_dir = "C:\\doit\\data\\"
    
# 저장될 파일위치와 이름을 자동 지정합니다
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min)

os.makedirs(f_dir+s+'-'+query_txt)
os.chdir(f_dir+s+'-'+query_txt)

ff_name = f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.txt'
fx_name = f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.xls'
fc_name = f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.csv'

#ff_name = input('검색 결과를 저장할 txt 파일경로와 이름을 지정하세요(예:c:\\temp\\test.txt): ')
#fc_name = input('검색 결과를 저장할 csv 파일경로와 이름을 지정하세요(예:c:\\temp\\test.csv): ')
#fx_name = input('검색 결과를 저장할 xls 파일경로와 이름을 지정하세요(예:c:\\temp\\test.xls): ')
# Out:
# 결과 파일을 저장할 폴더명만 쓰세요(없으면 :c:\doit\data\):

# %%
##Step 3. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.
path = "c:/doit/chromedriver_win32/chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get("https://korean.visitkorea.or.kr/main/main.html")
time.sleep(2)  # 창이 모두 열릴 때 까지 2초 기다립니다.

#코로나 안내 팝업창 있을 경우 닫기 클릭하기 
try :
    driver.find_element_by_xpath('//*[@id="safetyStay1"]/div/div/div/button').click()
except :
    print("안내 팝업창이 없습니다")
    
##Step 4. 검색창의 이름을 찾아서 검색어를 입력합니다

#driver.find_element_by_id("btnSearch").click()  ## 검색 디폴트값에 따라 움직이는데 예외처리 방법으로 해결?

driver.find_element_by_id("btnSearch").click()

element = driver.find_element_by_id("inp_search")

try :
    element.send_keys(query_txt)  # 검색 단추가 없어서 에러나면 다시 한번 눌러서 검색창을 띠움
except:
    driver.find_element_by_id("btnSearch").click()
    element = driver.find_element_by_id("inp_search")
    element.send_keys(query_txt)

#Step 3. 검색 버튼을 눌러 실행합니다

driver.find_element_by_link_text("검색").click()

# %%
# Step 4. 현재 페이지에 있는 내용을 화면에 출력하기

time.sleep(1)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
content_list = soup.find('ul',class_='list_thumType flnon')

# print(content_list)

# %%
# 소주제 1: 특정 항목들을 분리해서 추출하기
no = 1
no2 =[ ]
contents2=[ ]
tags2=[ ]

for i in content_list:
    no2.append(no)
    print('번호:',no)
    
    contents = i.find('div','tit').get_text( )
    contents2.append(contents)
    print('내용:',contents.strip())
    
    tag = i.find('p','tag').get_text()
    tags2.append(tag)
    print('태그:',tag.strip())
    print("\n")
    
    no += 1
# Out:
# 번호: 1
# 내용: 느릿하거나 우아하거나 열정적인 가을 원주 여행
# 태그: #장애인추천코스#원주가볼만한곳#원주당일코스#치악산금강소나무숲길#원주옻문화센터#원주드림체육관#원주역사박물관#원주한지테마파크#돼지문화원#뮤지엄산#간현유원지#원주1박2일코스#원주2박3일코스#무장애여행지#장애인추천여행지#가을여행
#
#
# 번호: 2
# 내용: 전어·꽃게·대하 가을 별미 삼총사와 함께한 서해안 가을 여행
# 태그: #공공누리#가을축제/행사#가을제철먹거리#가을제철음식#가을가볼만한곳#서해안가볼만한곳#먹방여행#구석구석미식회
#
#
# 번호: 3
# 내용: 가을은 역시 원주, 원주로 떠나는 가을 여행 원츄!
# 태그: #가을여행#가을1박2일#원주1박2일#원주여행#출렁다리#이색책방#레일바이크#책과함께_향기로운여정
#
#
# 번호: 4
# 내용: 은빛 억새와 황금 들녘, 서해 낙조가 어우러진 보령 오서산 가을 여행
# 태그: #보령가볼만한곳#오서산#억새군락지#오서산자연휴양림#힐링여행#휴양여행#트레킹#월정사#단풍여행#공공누리#억새군락지#가을가볼만한곳#가을여행
#
#
# 번호: 5
# 내용: 중앙선 따라 떠나는 늦가을 간이역 여행
# 태그: #간이역여행#감성여행#가을여행지추천#가을여행#기차여행#간이역
#
#
# 번호: 6
# 내용: 한국관광공사 추천 9월 걷기여행길, 초가을의 선선함을 만끽하러 가는 길
# 태그: #한국관광걷기여행길6선#걷기여행#가을여행#평화누리길#염하강철책길#김포가볼만한곳#낙동강세평하늘길#봉화가볼만한곳#트레킹코스#간절곶소망길#울주가볼만한곳#강화나들길#강화도령첫사랑길#강화가볼만한곳#강화산성#남도삼백리길#순천만갈대길#순천가볼만한곳#서산아라메길#녹색길#서산가볼만한곳#해미읍성#힐링#걷기여행길#추천!가을걷기_여행길#10월가볼만한곳
#
#
# 번호: 7
# 내용: 가까이에서 느껴본 가을 내음, 포천/연천 가을여행 스팟
# 태그: #가을여행#포천가볼만한곳#포천아트밸리#포천여행#산사원#산정호수#호로고루#연천가볼만한곳#연천여행#11월가볼만한곳#12월가볼만한곳#10월가볼만한곳#늦가을여행#가을여행코스#가을여행의_정석#끝가을이_아쉬울때
#
#
# 번호: 8
# 내용: 해발 700m 숲의 하룻밤, 이색 체험 태백 가을 여행
# 태그: #강원도#태백#태백고원자연휴양림#철암단풍군락지#단풍#철암탄광역사촌#365세이프타운#통리장#자연#가을#가족#친구#연인#여행#추천가볼만한곳#태백가볼만한곳#태백당일코스#태백1박2일코스#태백맛집#태백축제#가을제철음식#2015년10월추천가볼만한곳#10월추천가볼만한곳
#
#
# 번호: 9
# 내용: 늦가을 바다의 맛과 풍경이 어우러진 여행, 충남 보령
# 태그: #어르신추천코스#보령가볼만한곳#보령당일코스#천북굴단지#충청수영성#성주산자연휴양림#개화예술공원#웅천돌문화공원#무창포해수욕장#보령1박2일코스#보령2박3일코스#무장애여행지#장애인추천여행지#미식여행#겨울제철음식#체험여행#어르신여행#가을제철먹거리
#
#
# 번호: 10
# 내용: 대추처럼 달콤한 충북알프스 가을 여행
# 태그: #충청북도#보은#충북알프스#충북알프스자연휴양림#오리숲길#황톳길체험장#법주사#배영숙산야초밥상#보은속리정이품송#속리산#가을#휴양림#체험#자연#가족#친구#연인#여행#추천가볼만한곳#보은가볼만한곳#보은당일코스#보은1박2일코스#보은맛집#보은축제#2015년10월추천가볼만한곳#10월추천가볼만한곳

# %%
# 소주제 2: 분리 수집된 데이터를 데이터 프레임으로 만들어서 csv , xls 형식으로 저장하기
# 출력 결과를 txt 파일로 저장하기
f = open(ff_name, 'a',encoding='UTF-8')
f.write(str(contents2))
f.write(str(tags2))
f.close( )
print(" txt 파일 저장 경로: %s" %ff_name)    
    
# 출력 결과를 표(데이터 프레임) 형태로 만들기
import pandas as pd

korea_trip = pd.DataFrame()
korea_trip['번호']=no2
korea_trip['내용']=contents2
korea_trip['태그']=tags2

# csv 형태로 저장하기
korea_trip.to_csv(fc_name,encoding="utf-8-sig")
print(" csv 파일 저장 경로: %s" %fc_name)

# 엑셀 형태로 저장하기
import xlwt   # pip install xlwt 실행 후 수행
korea_trip.to_excel(fx_name)
print(" xls 파일 저장 경로: %s" %fx_name)
# Out:
#  txt 파일 저장 경로: C:\doit\data\2020-09-28-10-58-가을 여행\2020-09-28-10-58-가을 여행.txt
#  csv 파일 저장 경로: C:\doit\data\2020-09-28-10-58-가을 여행\2020-09-28-10-58-가을 여행.csv
#  xls 파일 저장 경로: C:\doit\data\2020-09-28-10-58-가을 여행\2020-09-28-10-58-가을 여행.xls

# %%
# c:\doit\ 폴더가 작업 폴더, c:\doit\data\ 폴더가 데이터 저장 폴더

## Step 0. 필요한 모듈과 라이브러리를 로딩하고 검색어를 입력 받습니다

from bs4 import BeautifulSoup     
from selenium import webdriver
import time
import sys
import os
import re
import math
import numpy
import pandas as pd
import xlwt

##Step 2. 사용자에게 검색어 키워드를 입력 받습니다.
print("=" *80)
print("대한민국 구석구석 사이트의 모든 여행지 정보 수집하기")
print("=" *80)

#query_txt = input('크롤링할 키워드는 무엇입니까?: ')
query_txt = '가을 여행'

f_dir = input("결과 파일을 저장할 폴더명만 쓰세요(없으면 :c:\\doit\\data\\):")

if f_dir == '':
    f_dir = "C:\\doit\\data\\"
    
# 저장될 파일위치와 이름을 자동 지정합니다
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min)

os.makedirs(f_dir+s+'-'+query_txt)
os.chdir(f_dir+s+'-'+query_txt)

ff_name = f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.txt'
fx_name = f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.xls'
fc_name = f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.csv'

#ff_name = input('검색 결과를 저장할 txt 파일경로와 이름을 지정하세요(예:c:\\temp\\test.txt): ')
#fc_name = input('검색 결과를 저장할 csv 파일경로와 이름을 지정하세요(예:c:\\temp\\test.csv): ')
#fx_name = input('검색 결과를 저장할 xls 파일경로와 이름을 지정하세요(예:c:\\temp\\test.xls): ')

##Step 3. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.
path = "c:/doit/chromedriver_win32/chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get("https://korean.visitkorea.or.kr/main/main.html")
time.sleep(2)  # 창이 모두 열릴 때 까지 2초 기다립니다.

#코로나 안내 팝업창 있을 경우 닫기 클릭하기 
try :
    driver.find_element_by_xpath('//*[@id="safetyStay1"]/div/div/div/button').click()
except :
    print("안내 팝업창이 없습니다")
    
##Step 4. 검색창의 이름을 찾아서 검색어를 입력하고 검색버튼을 실행합니다. 

#driver.find_element_by_id("btnSearch").click()  ## 검색 디폴트값에 따라 움직이는데 예외처리 방법으로 해결?

driver.find_element_by_id("btnSearch").click()

element = driver.find_element_by_id("inp_search")

try :
    element.send_keys(query_txt)  # 검색 단추가 없어서 에러나면 다시 한번 눌러서 검색창을 띠움
except:
    driver.find_element_by_id("btnSearch").click()
    element = driver.find_element_by_id("inp_search")
    element.send_keys(query_txt)

driver.find_element_by_link_text("검색").click()

# Step 4. 현재 페이지에 있는 내용을 화면에 출력하기

time.sleep(1)

html = driver.page_source   # 검색으로 나온 웹페이지 전체를 읽음
soup = BeautifulSoup(html, 'html.parser')  # 해당 페이지를 BS로 파싱
content_list = soup.find('ul',class_='list_thumType flnon') # 내용 중 해당 부분만 검색해서 리스트로

print(content_list)
print(len(content_list))

# 소주제 1: 특정 항목들을 분리해서 추출하기
no = 1
no2 =[ ]
contents2=[ ]
tags2=[ ]

for i in content_list:
    no2.append(no)
    print('번호:',no)
    
    contents = i.find('div','tit').get_text( )
    contents2.append(contents)
    print('제목:',contents.strip())
    
    tag = i.find('p','tag').get_text()
    tags2.append(tag)
    print('태그:',tag.strip())
    print("\n")
    
    no += 1
    
# 소주제 2: 분리 수집된 데이터를 데이터 프레임으로 만들어서 csv , xls 형식으로 저장하기
# 출력 결과를 txt 파일로 저장하기
f = open(ff_name, 'a',encoding='UTF-8')
f.write(str(contents2))
f.write(str(tags2))
f.close( )
print(" txt 파일 저장 경로: %s" %ff_name)    
    
# 출력 결과를 표(데이터 프레임) 형태로 만들기
import pandas as pd

korea_trip = pd.DataFrame()
korea_trip['번호']=no2
korea_trip['제목']=contents2
korea_trip['태그']=tags2

# csv 형태로 저장하기
korea_trip.to_csv(fc_name,encoding="utf-8-sig")  # csv 파일 인코딩은 'utf-8-sig' 인 것에 유의
print(" csv 파일 저장 경로: %s" %fc_name)

# 엑셀 형태로 저장하기
import xlwt   # pip install xlwt 실행 후 수행
korea_trip.to_excel(fx_name)
print(" xls 파일 저장 경로: %s" %fx_name)
# Out:
# ================================================================================
# 대한민국 구석구석 사이트의 모든 여행지 정보 수집하기
# ================================================================================
# 결과 파일을 저장할 폴더명만 쓰세요(없으면 :c:\doit\data\):
# <ul class="list_thumType flnon"><li class="bdr_nor"><div class="photo"><a href="javascript:" onclick='goDetail("304","e418f85b-47c1-4931-aac0-7e920b7bc6e0")'><img alt="느릿하거나 우아하거나 열정적인 가을 원주 여행" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=ceb7ac33-dac5-4960-928f-46427eff47ee"/></a></div><div class="area_txt"> <div class="tit"> <a href="javascript:" onclick='goDetail("304","e418f85b-47c1-4931-aac0-7e920b7bc6e0")'>느릿하거나 우아하거나 열정적인 <!--HS-->가을<!--HE--> 원주 <!--HS-->여행<!--HE--></a> </div> <p>강원도 원주시</p> <p class="tag"><span>#장애인추천코스</span><span>#원주가볼만한곳</span><span>#원주당일코스</span><span>#치악산금강소나무숲길</span><span>#원주옻문화센터</span><span>#원주드림체육관</span><span>#원주역사박물관</span><span>#원주한지테마파크</span><span>#돼지문화원</span><span>#뮤지엄산</span><span>#간현유원지</span><span>#원주1박2일코스</span><span>#원주2박3일코스</span><span>#무장애여행지</span><span>#장애인추천여행지</span><span>#가을여행</span> </p></div><button class="btn_view" title="내용 더보기" type="button">더보기</button><div class="pop_subMenu"> <ul> <li class="btn_far"><a href="javascript:" onclick='setFavoContent("e418f85b-47c1-4931-aac0-7e920b7bc6e0")'>즐겨찾기</a></li> <li class="btn_share" id="e418f85b-47c1-4931-aac0-7e920b7bc6e0"><a href="javascript:" onclick='getShareInfo("%EB%8A%90%EB%A6%BF%ED%95%98%EA%B1%B0%EB%82%98%20%EC%9A%B0%EC%95%84%ED%95%98%EA%B1%B0%EB%82%98%20%EC%97%B4%EC%A0%95%EC%A0%81%EC%9D%B8%20%3C!HS%3E%EA%B0%80%EC%9D%84%3C!HE%3E%20%EC%9B%90%EC%A3%BC%20%3C!HS%3E%EC%97%AC%ED%96%89%3C!HE%3E","ceb7ac33-dac5-4960-928f-46427eff47ee","e418f85b-47c1-4931-aac0-7e920b7bc6e0","304");'>공유하기</a></li> </ul></div></li><li class="bdr_nor"><div class="photo"><a href="javascript:" onclick='goDetail("304","fe0c20bd-1e43-411d-8368-043582a79a0b")'><img alt="전어·꽃게·대하 가을 별미 삼총사와 함께한 서해안 가을 여행" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=bc872aa0-9c96-4ef1-9a34-2d0d95cfd157"/></a></div><div class="area_txt"> <div class="tit"> <a href="javascript:" onclick='goDetail("304","fe0c20bd-1e43-411d-8368-043582a79a0b")'>전어·꽃게·대하 <!--HS-->가을<!--HE--> 별미 삼총사와 함께한 서해안 <!--HS-->가을<!--HE--> <!--HS-->여행<!--HE--></a> </div> <p>충청남도 서천군</p> <p class="tag"><span>#공공누리</span><span>#가을축제/행사</span><span>#가을제철먹거리</span><span>#가을제철음식</span><span>#가을가볼만한곳</span><span>#서해안가볼만한곳</span><span>#먹방여행</span><span>#구석구석미식회</span> </p></div><button class="btn_view" title="내용 더보기" type="button">더보기</button><div class="pop_subMenu"> <ul> <li class="btn_far"><a href="javascript:" onclick='setFavoContent("fe0c20bd-1e43-411d-8368-043582a79a0b")'>즐겨찾기</a></li> <li class="btn_share" id="fe0c20bd-1e43-411d-8368-043582a79a0b"><a href="javascript:" onclick='getShareInfo("%EC%A0%84%EC%96%B4%C2%B7%EA%BD%83%EA%B2%8C%C2%B7%EB%8C%80%ED%95%98%20%3C!HS%3E%EA%B0%80%EC%9D%84%3C!HE%3E%20%EB%B3%84%EB%AF%B8%20%EC%82%BC%EC%B4%9D%EC%82%AC%EC%99%80%20%ED%95%A8%EA%BB%98%ED%95%9C%20%EC%84%9C%ED%95%B4%EC%95%88%20%3C!HS%3E%EA%B0%80%EC%9D%84%3C!HE%3E%20%3C!HS%3E%EC%97%AC%ED%96%89%3C!HE%3E","bc872aa0-9c96-4ef1-9a34-2d0d95cfd157","fe0c20bd-1e43-411d-8368-043582a79a0b","304");'>공유하기</a></li> </ul></div></li><li class="bdr_nor"><div class="photo"><a href="javascript:" onclick='goDetail("304","3d1e9fc4-1f99-490d-a623-24e875bc3f48")'><img alt="가을은 역시 원주, 원주로 떠나는 가을 여행 원츄!" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=fecc3863-ef1a-43d2-b818-ce15788b8db2"/></a></div><div class="area_txt"> <div class="tit"> <a href="javascript:" onclick='goDetail("304","3d1e9fc4-1f99-490d-a623-24e875bc3f48")'><!--HS-->가을<!--HE-->은 역시 원주, 원주로 떠나는 <!--HS-->가을<!--HE--> <!--HS-->여행<!--HE--> 원츄!</a> </div> <p>강원도 원주시</p> <p class="tag"><span>#가을여행</span><span>#가을1박2일</span><span>#원주1박2일</span><span>#원주여행</span><span>#출렁다리</span><span>#이색책방</span><span>#레일바이크</span><span>#책과함께_향기로운여정</span> </p></div><button class="btn_view" title="내용 더보기" type="button">더보기</button><div class="pop_subMenu"> <ul> <li class="btn_far"><a href="javascript:" onclick='setFavoContent("3d1e9fc4-1f99-490d-a623-24e875bc3f48")'>즐겨찾기</a></li> <li class="btn_share" id="3d1e9fc4-1f99-490d-a623-24e875bc3f48"><a href="java ...
# 10
# 번호: 1
# 내용: 느릿하거나 우아하거나 열정적인 가을 원주 여행
# 태그: #장애인추천코스#원주가볼만한곳#원주당일코스#치악산금강소나무숲길#원주옻문화센터#원주드림체육관#원주역사박물관#원주한지테마파크#돼지문화원#뮤지엄산#간현유원지#원주1박2일코스#원주2박3일코스#무장애여행지#장애인추천여행지#가을여행
#
#
# 번호: 2
# 내용: 전어·꽃게·대하 가을 별미 삼총사와 함께한 서해안 가을 여행
# 태그: #공공누리#가을축제/행사#가을제철먹거리#가을제철음식#가을가볼만한곳#서해안가볼만한곳#먹방여행#구석구석미식회
#
#
# 번호: 3
# 내용: 가을은 역시 원주, 원주로 떠나는 가을 여행 원츄!
# 태그: #가을여행#가을1박2일#원주1박2일#원주여행#출렁다리#이색책방#레일바이크#책과함께_향기로운여정
#
#
# 번호: 4
# 내용: 은빛 억새와 황금 들녘, 서해 낙조가 어우러진 보령 오서산 가을 여행
# 태그: #보령가볼만한곳#오서산#억새군락지#오서산자연휴양림#힐링여행#휴양여행#트레킹#월정사#단풍여행#공공누리#억새군락지#가을가볼만한곳#가을여행
#
#
# 번호: 5
# 내용: 중앙선 따라 떠나는 늦가을 간이역 여행
# 태그: #간이역여행#감성여행#가을여행지추천#가을여행#기차여행#간이역
#
#
# 번호: 6
# 내용: 한국관광공사 추천 9월 걷기여행길, 초가을의 선선함을 만끽하러 가는 길
# 태그: #한국관광걷기여행길6선#걷기여행#가을여행#평화누리길#염하강철책길#김포가볼만한곳#낙동강세평하늘길#봉화가볼만한곳#트레킹코스#간절곶소망길#울주가볼만한곳#강화나들길#강화도령첫사랑길#강화가볼만한곳#강화산성#남도삼백리길#순천만갈대길#순천가볼만한곳#서산아라메길#녹색길#서산가볼만한곳#해미읍성#힐링#걷기여행길#추천!가을걷기_여행길#10월가볼만한곳
#
#
# 번호: 7
# 내용: 가까이에서 느껴본 가을 내음, 포천/연천 가을여행 스팟
# 태그: #가을여행#포천가볼만한곳#포천아트밸리#포천여행#산사원#산정호수#호로고루#연천가볼만한곳#연천여행#11월가볼만한곳#12월가볼만한곳#10월가볼만한곳#늦가을여행#가을여행코스#가을여행의_정석#끝가을이_아쉬울때
#
#
# 번호: 8
# 내용: 해발 700m 숲의 하룻밤, 이색 체험 태백 가을 여행
# 태그: #강원도#태백#태백고원자연휴양림#철암단풍군락지#단풍#철암탄광역사촌#365세이프타운#통리장#자연#가을#가족#친구#연인#여행#추천가볼만한곳#태백가볼만한곳#태백당일코스#태백1박2일코스#태백맛집#태백축제#가을제철음식#2015년10월추천가볼만한곳#10월추천가볼만한곳
#
#
# 번호: 9
# 내용: 늦가을 바다의 맛과 풍경이 어우러진 여행, 충남 보령
# 태그: #어르신추천코스#보령가볼만한곳#보령당일코스#천북굴단지#충청수영성#성주산자연휴양림#개화예술공원#웅천돌문화공원#무창포해수욕장#보령1박2일코스#보령2박3일코스#무장애여행지#장애인추천여행지#미식여행#겨울제철음식#체험여행#어르신여행#가을제철먹거리
#
#
# 번호: 10
# 내용: 대추처럼 달콤한 충북알프스 가을 여행
# 태그: #충청북도#보은#충북알프스#충북알프스자연휴양림#오리숲길#황톳길체험장#법주사#배영숙산야초밥상#보은속리정이품송#속리산#가을#휴양림#체험#자연#가족#친구#연인#여행#추천가볼만한곳#보은가볼만한곳#보은당일코스#보은1박2일코스#보은맛집#보은축제#2015년10월추천가볼만한곳#10월추천가볼만한곳
#
#
#  txt 파일 저장 경로: C:\doit\data\2020-09-28-11-27-가을 여행\2020-09-28-11-27-가을 여행.txt
#  csv 파일 저장 경로: C:\doit\data\2020-09-28-11-27-가을 여행\2020-09-28-11-27-가을 여행.csv
#  xls 파일 저장 경로: C:\doit\data\2020-09-28-11-27-가을 여행\2020-09-28-11-27-가을 여행.xls
